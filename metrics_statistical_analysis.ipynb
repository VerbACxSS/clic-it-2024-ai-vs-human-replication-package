# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Libs

# %%
import json

import pandas as pd

from cliffs_delta import cliffs_delta
from scipy.stats import wilcoxon, ttest_rel, pearsonr, spearmanr, kendalltau

# %% [markdown]
# ## Utils

# %%
def do_stat_analysis(original_df, human_df, llm_df):
    results = []

    original = original_df['gulpease']
    human = human_df['gulpease']
    llm = llm_df['gulpease']
    results.append({
        "metrics": "gulpease",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = original_df['flesch_vacca']
    human = human_df['flesch_vacca']
    llm = llm_df['flesch_vacca']
    results.append({
        "metrics": "flesch_vacca",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = (original_df['n_vdb'] / original_df['n_tokens'] * 100.0).fillna(0)
    human = (human_df['n_vdb'] / human_df['n_tokens'] * 100.0).fillna(0)
    llm = (llm_df['n_vdb'] / llm_df['n_tokens'] * 100.0).fillna(0)
    results.append({
        "metrics": "vdb",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = (original_df['n_passive_verbs'] / original_df['n_verbs'] * 100.0).fillna(0)
    human= (human_df['n_passive_verbs'] / human_df['n_verbs'] * 100.0).fillna(0)
    llm = (llm_df['n_passive_verbs'] / llm_df['n_verbs'] * 100.0).fillna(0)
    results.append({
        "metrics": "passive",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = original_df['readit_base']
    human = human_df['readit_base']
    llm = llm_df['readit_base']
    results.append({
        "metrics": "readit_base",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = original_df['readit_lexical']
    human = human_df['readit_lexical']
    llm = llm_df['readit_lexical']
    results.append({
        "metrics": "readit_lexical",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })
    
    original = original_df['readit_syntactic']
    human = human_df['readit_syntactic']
    llm = llm_df['readit_syntactic']
    results.append({
        "metrics": "readit_syntactic",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    original = original_df['readit_global']
    human = human_df['readit_global']
    llm = llm_df['readit_global']
    results.append({
        "metrics": "readit_global",
        "original_mean": round(original.mean(), 2),
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        # "p_value": wilcoxon(human - original, llm - original)[1],
        # "p_value_ok": wilcoxon(human - original, llm - original)[1] < 0.05,
        # "eff_size": cliffs_delta(human - original, llm - original)[1],
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if (llm - original).mean() > (human - original).mean() else 'negative'
    })

    human = (human_df['semantic_similarity']).fillna(0)
    llm = (llm_df['semantic_similarity']).fillna(0)
    results.append({
        "metrics": "semantic_similarity",
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if llm.mean() > human.mean() else 'negative'
    })

    human = human_df['editdistance'] / pd.concat([original_df['n_chars'], human_df['n_chars']], axis=1).max(axis=1) * 100
    llm = llm_df['editdistance'] / pd.concat([original_df['n_chars'], llm_df['n_chars']], axis=1).max(axis=1) * 100
    results.append({
        "metrics": "editdistance",
        "human_mean": round(human.mean(), 2),
        "llm_mean": round(llm.mean(), 2),
        "p_value": wilcoxon(human, llm)[1],
        "p_value_ok": wilcoxon(human, llm)[1] < 0.05,
        "eff_size": cliffs_delta(human, llm)[1],
        "eff": 'positive' if llm.mean() > human.mean() else 'negative'
    })

    return pd.DataFrame(results)

# %% [markdown]
# ## Load data

# %%
CORPUS_NAMES = ['original', 'human1', 'human2', 'gpt3_5', 'gpt4', 'llama3', 'phi3']

# %%
dfs_maps = dict()
jsons_maps = dict()
for CORPUS_NAME in CORPUS_NAMES:
  print(CORPUS_NAME)
  tmp_df = pd.read_csv(f'simplified_corpora_with_metrics/{CORPUS_NAME}.csv', encoding='utf-8')
  tmp_df = tmp_df.sort_values(by=['document', 'paragraph_index'])
  print(tmp_df.shape)
  dfs_maps[CORPUS_NAME] = tmp_df
# Out:
# original
# (619, 41)
# human1
# (619, 48)
# human2
# (619, 48)
# gpt3_5
# (619, 48)
# gpt4
# (619, 48)
# llama3
# (619, 48)
# phi3
# (619, 48)

# %%
def corr_analysis(original_df, simpl_df):
    human_s = dfs_maps['human1']['semantic_similarity']
    human_e = dfs_maps['human1']['editdistance'] / pd.concat([dfs_maps['original']['n_chars'], dfs_maps['human1']['n_chars']], axis=1).max(axis=1) * 100
    kendalltau(human_s, human_e)

# %% [markdown]
# ## GPT-4

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human1'], dfs_maps['gpt4'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       49.72     51.34  6.488534e-10
# 1         flesch_vacca          19.97       34.23     36.75  9.618789e-05
# 2                  vdb          73.24       80.44     81.07  1.078430e-02
# 3              passive          20.87       15.78     12.00  4.491658e-04
# 4          readit_base           0.76        0.69      0.55  2.192894e-24
# 5       readit_lexical           0.94        0.85      0.90  3.183687e-08
# 6     readit_syntactic           0.64        0.53      0.30  1.469038e-29
# 7        readit_global           0.86        0.69      0.55  3.151567e-13
# 8  semantic_similarity            NaN       96.52     95.80  3.202180e-12
# 9         editdistance            NaN       35.84     52.14  3.703462e-60
#
#    p_value_ok    eff_size       eff
# 0        True  negligible  positive
# 1        True  negligible  positive
# 2        True  negligible  positive
# 3        True  negligible  negative
# 4        True       small  negative
# 5        True  negligible  positive
# 6        True       small  negative
# 7        True       small  negative
# 8        True       small  negative
# 9        True       large  positive

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human2'], dfs_maps['gpt4'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       50.64     51.34  9.239853e-03
# 1         flesch_vacca          19.97       33.63     36.75  7.146294e-06
# 2                  vdb          73.24       76.89     81.07  1.656554e-34
# 3              passive          20.87       17.71     12.00  1.079617e-05
# 4          readit_base           0.76        0.51      0.55  2.920430e-02
# 5       readit_lexical           0.94        0.90      0.90  3.390760e-01
# 6     readit_syntactic           0.64        0.40      0.30  2.468327e-09
# 7        readit_global           0.86        0.61      0.55  6.994563e-05
# 8  semantic_similarity            NaN       97.26     95.80  1.964740e-37
# 9         editdistance            NaN       29.20     52.14  2.352919e-82
#
#    p_value_ok    eff_size       eff
# 0        True  negligible  positive
# 1        True  negligible  positive
# 2        True       small  positive
# 3        True  negligible  negative
# 4        True  negligible  positive
# 5       False  negligible  positive
# 6        True  negligible  negative
# 7        True  negligible  negative
# 8        True      medium  negative
# 9        True       large  positive

# %% [markdown]
# ## GPT3

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human1'], dfs_maps['gpt3_5'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       49.72     48.49  7.291712e-06
# 1         flesch_vacca          19.97       34.23     30.33  3.425211e-09
# 2                  vdb          73.24       80.44     78.28  3.703430e-11
# 3              passive          20.87       15.78     13.99  1.065951e-01
# 4          readit_base           0.76        0.69      0.67  5.206260e-03
# 5       readit_lexical           0.94        0.85      0.92  1.029182e-15
# 6     readit_syntactic           0.64        0.53      0.38  8.293399e-17
# 7        readit_global           0.86        0.69      0.69  4.434029e-01
# 8  semantic_similarity            NaN       96.52     96.06  5.769499e-08
# 9         editdistance            NaN       35.84     49.21  3.169896e-46
#
#    p_value_ok    eff_size       eff
# 0        True  negligible  negative
# 1        True  negligible  negative
# 2        True  negligible  negative
# 3       False  negligible  negative
# 4        True  negligible  negative
# 5        True  negligible  positive
# 6        True       small  negative
# 7       False  negligible  negative
# 8        True       small  negative
# 9        True      medium  positive

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human2'], dfs_maps['gpt3_5'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       50.64     48.49  6.721741e-10
# 1         flesch_vacca          19.97       33.63     30.33  3.103557e-07
# 2                  vdb          73.24       76.89     78.28  2.770521e-05
# 3              passive          20.87       17.71     13.99  7.295083e-03
# 4          readit_base           0.76        0.51      0.67  2.442149e-20
# 5       readit_lexical           0.94        0.90      0.92  9.144701e-03
# 6     readit_syntactic           0.64        0.40      0.38  1.507124e-01
# 7        readit_global           0.86        0.61      0.69  3.243806e-04
# 8  semantic_similarity            NaN       97.26     96.06  2.902262e-25
# 9         editdistance            NaN       29.20     49.21  9.469370e-70
#
#    p_value_ok    eff_size       eff
# 0        True       small  negative
# 1        True  negligible  negative
# 2        True  negligible  positive
# 3        True  negligible  negative
# 4        True       small  positive
# 5        True  negligible  positive
# 6       False  negligible  negative
# 7        True  negligible  positive
# 8        True      medium  negative
# 9        True       large  positive

# %% [markdown]
# ## LLAMA

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human1'], dfs_maps['llama3'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       49.72     50.26  7.797009e-03
# 1         flesch_vacca          19.97       34.23     34.09  7.133791e-01
# 2                  vdb          73.24       80.44     80.18  4.700749e-01
# 3              passive          20.87       15.78     15.81  7.221885e-01
# 4          readit_base           0.76        0.69      0.58  1.420325e-17
# 5       readit_lexical           0.94        0.85      0.77  2.034657e-05
# 6     readit_syntactic           0.64        0.53      0.41  1.111975e-08
# 7        readit_global           0.86        0.69      0.59  5.786003e-08
# 8  semantic_similarity            NaN       96.52     94.96  7.248210e-27
# 9         editdistance            NaN       35.84     55.48  8.082643e-63
#
#    p_value_ok    eff_size       eff
# 0        True  negligible  positive
# 1       False  negligible  negative
# 2       False  negligible  negative
# 3       False  negligible  positive
# 4        True       small  negative
# 5        True  negligible  negative
# 6        True       small  negative
# 7        True       small  negative
# 8        True      medium  negative
# 9        True       large  positive

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human2'], dfs_maps['llama3'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       50.64     50.26  5.739604e-01
# 1         flesch_vacca          19.97       33.63     34.09  4.316865e-01
# 2                  vdb          73.24       76.89     80.18  7.187039e-19
# 3              passive          20.87       17.71     15.81  1.313919e-01
# 4          readit_base           0.76        0.51      0.58  7.322538e-06
# 5       readit_lexical           0.94        0.90      0.77  3.270669e-15
# 6     readit_syntactic           0.64        0.40      0.41  4.777445e-01
# 7        readit_global           0.86        0.61      0.59  2.693113e-01
# 8  semantic_similarity            NaN       97.26     94.96  2.322423e-50
# 9         editdistance            NaN       29.20     55.48  3.131136e-85
#
#    p_value_ok    eff_size       eff
# 0       False  negligible  negative
# 1       False  negligible  positive
# 2        True       small  positive
# 3       False  negligible  negative
# 4        True  negligible  positive
# 5        True       small  negative
# 6       False  negligible  positive
# 7       False  negligible  negative
# 8        True       large  negative
# 9        True       large  positive

# %% [markdown]
# ## Phi3

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human1'], dfs_maps['phi3'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       49.72     50.16  1.344847e-02
# 1         flesch_vacca          19.97       34.23     33.75  3.913985e-01
# 2                  vdb          73.24       80.44     80.16  5.135307e-01
# 3              passive          20.87       15.78     15.72  7.426201e-01
# 4          readit_base           0.76        0.69      0.58  1.306924e-17
# 5       readit_lexical           0.94        0.85      0.76  1.171692e-07
# 6     readit_syntactic           0.64        0.53      0.41  1.360289e-08
# 7        readit_global           0.86        0.69      0.58  5.572763e-08
# 8  semantic_similarity            NaN       96.52     94.96  4.993544e-27
# 9         editdistance            NaN       35.84     55.44  1.504193e-63
#
#    p_value_ok    eff_size       eff
# 0        True  negligible  positive
# 1       False  negligible  negative
# 2       False  negligible  negative
# 3       False  negligible  negative
# 4        True       small  negative
# 5        True  negligible  negative
# 6        True       small  negative
# 7        True       small  negative
# 8        True      medium  negative
# 9        True       large  positive

# %%
do_stat_analysis(dfs_maps['original'], dfs_maps['human2'], dfs_maps['phi3'])
# Out:
#                metrics  original_mean  human_mean  llm_mean       p_value  \
# 0             gulpease          44.31       50.64     50.16  4.153815e-01
# 1         flesch_vacca          19.97       33.63     33.75  8.484467e-01
# 2                  vdb          73.24       76.89     80.16  1.164671e-18
# 3              passive          20.87       17.71     15.72  1.063253e-01
# 4          readit_base           0.76        0.51      0.58  2.587388e-05
# 5       readit_lexical           0.94        0.90      0.76  3.038695e-18
# 6     readit_syntactic           0.64        0.40      0.41  1.945200e-01
# 7        readit_global           0.86        0.61      0.58  1.770465e-01
# 8  semantic_similarity            NaN       97.26     94.96  1.147606e-50
# 9         editdistance            NaN       29.20     55.44  3.003740e-85
#
#    p_value_ok    eff_size       eff
# 0       False  negligible  negative
# 1       False  negligible  positive
# 2        True       small  positive
# 3       False  negligible  negative
# 4        True  negligible  positive
# 5        True       small  negative
# 6       False  negligible  positive
# 7       False  negligible  negative
# 8        True       large  negative
# 9        True       large  positive

# %% [markdown]
# # Correlation (semantic_similarity vs editdistance)

# %%
d = []
for CORPUS_NAME, df in dfs_maps.items():
    if CORPUS_NAME == 'original':
        continue
    s = df['semantic_similarity']
    e = df['editdistance'] / pd.concat([dfs_maps['original']['n_chars'], df['n_chars']], axis=1).max(axis=1) * 100
    d.append({
        'corpus': CORPUS_NAME,
        'pearsonr': pearsonr(s, e)[0],
        'pearsonr_ok': pearsonr(s, e)[1] < 0.05,
        'spearmanr': spearmanr(s, e)[0],
        'spearmanr_ok': spearmanr(s, e)[1] < 0.05,
        'kendalltau': kendalltau(s, e)[0],
        'kendalltau_ok': kendalltau(s, e)[1] < 0.05,
    })

pd.DataFrame(d).head(20)
# Out:
#    corpus  pearsonr  pearsonr_ok  spearmanr  spearmanr_ok  kendalltau  \
# 0  human1 -0.780257         True  -0.817790          True   -0.628587
# 1  human2 -0.815397         True  -0.854619          True   -0.679401
# 2  gpt3_5 -0.529278         True  -0.547440          True   -0.381988
# 3    gpt4 -0.555168         True  -0.529365          True   -0.374514
# 4  llama3 -0.714993         True  -0.659249          True   -0.481106
# 5    phi3 -0.719746         True  -0.661604          True   -0.483106
#
#    kendalltau_ok
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
